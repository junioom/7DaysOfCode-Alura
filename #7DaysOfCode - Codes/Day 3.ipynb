# %% [markdown]
# # DIA 1

# %% [markdown]
# ## Importando as bases de dados dos emprestimos e concatenando todas.

# %%
import pandas as pd

base_url = 'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/'

files = ['emprestimos-20101.csv',
         'emprestimos-20102.csv',
         'emprestimos-20111.csv',
         'emprestimos-20112.csv',
         'emprestimos-20121.csv',
         'emprestimos-20122.csv',
         'emprestimos-20131.csv',
         'emprestimos-20132.csv',
         'emprestimos-20141.csv',
         'emprestimos-20142.csv',
         'emprestimos-20151.csv',
         'emprestimos-20152.csv',
         'emprestimos-20161.csv',
         'emprestimos-20162.csv',
         'emprestimos-20171.csv',
         'emprestimos-20172.csv',
         'emprestimos-20181.csv',
         'emprestimos-20182.csv',
         'emprestimos-20191.csv',
         'emprestimos-20192.csv',
         'emprestimos-20201.csv']


url_file_emprestimo = [base_url + file for file in files]

dfs_emprestimos = []

for url in url_file_emprestimo:
    df = pd.read_csv(url)
    dfs_emprestimos.append(df)

df_combinado_emprestimo = pd.concat(dfs_emprestimos, ignore_index=True)

# %% [markdown]
# ## Verificando se há duplicatas (Informações duplicadas)

# %%
df_combinado_emprestimo.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# 2461099        2012008348     2016/06/27 20:35:46.855000000  2016/06/14 11:20:33.254000000  2016/07/11 14:37:29.000000000  2.015022e+09        ALUNO DE GRADUAÇÃO        2
#                                                                                                                                                                         ..
# 1443389        2011018954     2013/03/22 13:18:55.037000000  2013/03/07 11:21:26.480000000  2013/04/08 20:26:07.000000000  2.010046e+09        ALUNO DE GRADUAÇÃO        1
# 1443390        2009056314     2013/03/21 09:28:45.689000000  2013/03/07 11:21:28.899000000  2013/04/05 18:18:00.000000000  2.011015e+09        ALUNO DE GRADUAÇÃO        1
# 1443393        2012037906     2013/03/20 20:17:10.574000000  2013/03/07 11:24:19.326000000  2013/03/25 08:58:44.000000000  2.011038e+09        ALUNO DE GRADUAÇÃO        1
# 1443395        2011033069     2013/04/07 01:06:51.679000000  2013/03/07 11:25:22.661000000  2013/05/07 16:19:34.000000000  2.011106e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 10322328       2014070441     2018/01/15 12:26:00.697000000  2017/12/29 18:21:09.060000000  2018/01/31 18:50:25.000000000  2.014063e+09        ALUNO DE GRADUAÇÃO        1
# Name: count, Length: 968028, dtype: int64

# %% [markdown]
# ### Removendo-as:

# %%
df_combinado_emprestimo = df_combinado_emprestimo.drop_duplicates()

display(df_combinado_emprestimo.value_counts())
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 2336122        2011033079     2016/11/21 02:01:58.488000000  2016/11/10 17:00:12.989000000  2016/12/02 14:21:49.000000000  2.016023e+09        ALUNO DE GRADUAÇÃO        1
# 2336103        2014085936     2016/11/25 19:25:36.215000000  2016/11/10 16:54:52.447000000  2016/12/13 14:30:52.000000000  2.014047e+09        ALUNO DE GRADUAÇÃO        1
# 2336104        2011027960     2016/11/23 17:27:54.642000000  2016/11/10 16:55:17.956000000  2016/11/28 10:32:38.000000000  2.016083e+09        ALUNO DE GRADUAÇÃO        1
# 2336105        2014000897     2016/12/02 15:02:53.356000000  2016/11/10 16:55:19.851000000  2016/12/23 13:53:23.000000000  2.014071e+09        ALUNO DE GRADUAÇÃO        1
#                                                                                                                                                                         ..
# 1443383        2010043058     2013/03/21 14:06:09.837000000  2013/03/07 11:17:25.008000000  2013/03/22 11:31:20.000000000  2.010023e+09        ALUNO DE GRADUAÇÃO        1
# 1443387        L147018        2013/03/21 19:43:42.047000000  2013/03/07 11:20:01.159000000  2013/04/04 10:50:22.000000000  2.013053e+09        ALUNO DE GRADUAÇÃO        1
# 1443389        2011018954     2013/03/22 13:18:55.037000000  2013/03/07 11:21:26.480000000  2013/04/08 20:26:07.000000000  2.010046e+09        ALUNO DE GRADUAÇÃO        1
# 1443390        2009056314     2013/03/21 09:28:45.689000000  2013/03/07 11:21:28.899000000  2013/04/05 18:18:00.000000000  2.011015e+09        ALUNO DE GRADUAÇÃO        1
# 10322328       2014070441     2018/01/15 12:26:00.697000000  2017/12/29 18:21:09.060000000  2018/01/31 18:50:25.000000000  2.014063e+09        ALUNO DE GRADUAÇÃO        1
# Name: count, Length: 968028, dtype: int64

# %% [markdown]
# ## Importando a segunda base de dados (Exemplares)

# %%
database_exemplares = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')
display(database_exemplares)
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# 3                          Biblioteca Central Zila Mamede         REGULAR
# 5                          Biblioteca Central Zila Mamede        ESPECIAL
# ...                                                   ...             ...
# 568580  Biblioteca Setorial do Núcleo de Educação da I...         REGULAR
# 568581                     Biblioteca Central Zila Mamede        ESPECIAL
# 568582                     Biblioteca Central Zila Mamede        ESPECIAL
# 568583                     Biblioteca Central Zila Mamede        ESPECIAL
# 568584                     Biblioteca Central Zila Mamede        ESPECIAL
#
#         localizacao  registro_sistema
# index
# 0               694                 1
# 1               688                 1
# 2               638                 1
# 3               616                 5
# 5               657                15
# ...             ...               ...
# 568580          951            268231
# 568581          997            268233
# 568582          987            268234
# 568583          764            268235
# 568584          962            268236
#
# [546237 rows x 7 columns]

# %% [markdown]
# ## Mesclando as duas bases de dados

# %%
df_final = df_combinado_emprestimo.merge(database_exemplares)
df_final.head(50)
# Out:
#     id_emprestimo codigo_barras                 data_renovacao  \
# 0          709684       L095049                            NaN
# 1          726965       L095049  2010/03/31 12:41:08.684000000
# 2          709685       L167050                            NaN
# 3          717763       L167050                            NaN
# 4          729996       L167050  2010/03/17 09:08:26.874000000
# 5          750168       L167050  2010/04/20 08:40:47.151000000
# 6          769478       L167050                            NaN
# 7          779650       L167050                            NaN
# 8          785791       L167050                            NaN
# 9          799721       L167050                            NaN
# 10         807187       L167050  2010/08/17 16:27:04.236000000
# 11         828113       L167050  2010/09/16 19:27:32.356000000
# 12         853907       L167050                            NaN
# 13         865334       L167050                            NaN
# 14         877850       L167050                            NaN
# 15         880244       L167050                            NaN
# 16         888767       L167050                            NaN
# 17         929007       L167050                            NaN
# 18         946307       L167050                            NaN
# 19         963971       L167050                            NaN
# 20         982999       L167050  2011/05/12 20:01:11.730000000
# 21        1005295       L167050  2011/06/09 16:18:33.713000000
# 22        1041880       L167050  2011/08/21 11:47:13.866000000
# 23        1069850       L167050                            NaN
# 24        1082240       L167050  2011/10/20 08:58:05.351000000
# 25        1129919       L167050  2011/12/18 16:10:00.716000000
# 26        1161624       L167050  2012/02/28 08:42:56.888000000
# 27        1203429       L167050  2012/04/09 22:05:18.634000000
# 28        1235247       L167050  2012/05/09 11:50:10.077000000
# 29        1252784       L167050                            NaN
# 30        1269377       L167050  2012/06/19 19:40:10.778000000
# 31        1283787       L167050  2012/08/05 08:01:41.836000000
# 32        1316376       L167050                            NaN
# 33        1332049       L167050  2012/10/01 17:47:15.411000000
# 34        1354375       L167050  2012/11/19 10:22:22.412000000
# 35        1388540       L167050                            NaN
# 36        1431357       L167050  2013/03/11 20:05:56.086000000
# 37        1489072       L167050  2013/05/08 07:36:52.343000000
# 38        1510668       L167050  2013/06/05 13:52:55.587000000
# 39        1552038       L167050  2013/08/14 16:40:27.300000000
# 40        1645247       L167050  2013/12/09 08:50:50.556000000
# 41        1668772       L167050                            NaN
# 42        1697605       L167050  2014/03/25 11:25:11.816000000
# 43        1747985       L167050  2014/05/19 17:00:56.079000000
# 44        1791285       L167050  2014/08/14 00:16:12.406000000
# 45        1817437       L167050  2014/09/11 16:44:05.917000000
# 46        1848256       L167050  2014/10/17 09:27:05.331000000
# 47        1880781       L167050                            NaN
# 48        1906307       L167050  2015/02/19 12:09:18.960000000
# 49        1936029       L167050  2015/03/22 10:49:04.848000000
#
#                   data_emprestimo                 data_devolucao  \
# 0   2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1   2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2   2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3   2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4   2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
# 5   2010/04/06 09:43:02.740000000  2010/05/05 18:33:53.974000000
# 6   2010/05/05 18:34:28.768000000  2010/05/21 18:59:56.315000000
# 7   2010/05/21 19:00:13.760000000  2010/06/01 18:41:16.000000000
# 8   2010/06/01 18:41:54.885000000  2010/07/01 21:19:58.000000000
# 9   2010/07/01 21:20:19.827000000  2010/07/13 10:29:56.000000000
# 10  2010/08/02 17:52:51.879000000  2010/09/01 17:43:52.000000000
# 11  2010/09/01 17:44:20.182000000  2010/10/11 16:39:50.000000000
Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 4   Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 5   Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 6   Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 7   Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 8   Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 9   Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 10  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 11  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 12  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 13  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 14  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 15  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 16  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 17  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 18  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 19  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 20  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 21  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 22  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 23  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 24  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 25  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 26  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 27  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 28  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 29  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 30  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 31  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 32  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 33  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 34  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 35  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 36  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 37  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 38  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 39  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 40  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 41  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 42  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 43  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 44  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 45  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 46  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 47  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 48  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 49  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
#
#     localizacao  registro_sistema
# 0           630              4225
# 1           630              4225
# 2           647             25009
# 3           647             25009
# 4           647             25009
# 5           647             25009
# 6           647             25009
# 7           647             25009
# 8           647             25009
# 9           647             25009
# 10          647             25009
# 11          647             25009
# 12          647             25009
# 13          647             25009
# 14          647             25009
# 15          647             25009
# 16          647             25009
# 17          647             25009
# 18          647             25009
# 19          647             25009
# 20          647             25009
# 21          647             25009
# 22          647             25009
# 23          647             25009
# 24          647             25009
# 25          647             25009
# 26          647             25009
# 27          647             25009
# 28          647             25009
# 29          647             25009
# 30          647             25009
# 31          647             25009
# 32          647             25009
# 33          647             25009
# 34          647             25009
# 35          647             25009
# 36          647             25009
# 37          647             25009
# 38          647             25009
# 39          647             25009
# 40          647             25009
# 41          647             25009
# 42          647             25009
# 43          647             25009
# 44          647             25009
# 45          647             25009
# 46          647             25009
# 47          647             25009
# 48          647             25009
# 49          647             25009

# %% [markdown]
# # DIA 2

# %% [markdown]
# ## Manipulando os dados

# %% [markdown]
# ### Adicionando uma nova conluna que coloca a classificação do número da coluna "localização"

# %% [markdown]
#  - 000 a 099: Generalidades. Ciência e conhecimento.
#  - 100 a 199: Filosofia e psicologia.
#  - 200 a 299: Religião.
#  - 300 a 399: Ciências sociais.
#  - 400 a 499: Classe vaga. Provisoriamente não ocupada.
#  - 500 a 599: Matemática e ciências naturais.
#  - 600 a 699: Ciências aplicadas.
#  - 700 a 799: Belas artes.
#  - 800 a 899: Linguagem. Língua. Linguística.
#  - 900 a 999: Geografia. Biografia. História."

# %%
def CDU_code(code):
  classification = ''
  if code < 99:
    classification = 'Generalidades. Ciência e conhecimento.'
    return classification
  elif code >= 100 and code <199:
    classification = 'Filosofia e psicologia.'
    return classification
  elif code >= 200 and code <299:
    classification = 'Religião.'
    return classification
  elif code >= 300 and code <399:
    classification = 'Ciências sociais.'
    return classification
  elif code >= 400 and code <499:
    classification = 'Classe vaga. Provisoriamente não ocupada.'
    return classification
  elif code >= 500 and code <599:
    classification = 'Matemática e ciências naturais.'
    return classification
  elif code >= 600 and code <699:
    classification = 'Ciências aplicadas.'
    return classification
  elif code >= 700 and code <799:
    classification = 'Belas artes.'
    return classification
  elif code >= 800 and code <899:
    classification = 'Linguagem. Língua. Linguística.'
    return classification
  elif code >= 900 and code <999:
    classification = 'Geografia. Biografia. História.'
    return classification
  else:
    return 'NaN'

lista_classes = []

for cell in df_final['localizacao']:
  lista_classes.append(CDU_code(cell))

df_final['classe_geral'] = lista_classes

df_final.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema         classe_geral
# 0              4225  Ciências aplicadas.
# 1              4225  Ciências aplicadas.
# 2             25009  Ciências aplicadas.
# 3             25009  Ciências aplicadas.
# 4             25009  Ciências aplicadas.

# %% [markdown]
# ### Excluindo a coluna "registro_sistema" por não ter relevancia na análise

# %%
df_final = df_final.drop('registro_sistema', axis=1)
df_final.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#           classe_geral
# 0  Ciências aplicadas.
# 1  Ciências aplicadas.
# 2  Ciências aplicadas.
# 3  Ciências aplicadas.
# 4  Ciências aplicadas.

# %% [markdown]
# ### Modificando o dtype da coluna "matricula_ou_siape" para string, a fim de ter uma melhor visualização

# %%
df_final['matricula_ou_siape'] = df_final['matricula_ou_siape'].astype('string')
df_final.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         726965       L095049 2010-03-31 12:41:08.684
# 2         709685       L167050                     NaT
# 3         717763       L167050                     NaT
# 4         729996       L167050 2010-03-17 09:08:26.874
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-03-01 12:40:56.212 2010-04-30 14:42:35.366       2009121584.0
# 2 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 3 2010-02-11 11:16:30.335 2010-03-04 08:54:32.262       2008050352.0
# 4 2010-03-04 13:36:26.599 2010-03-31 18:04:29.669        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema
# 0              4225
# 1              4225
# 2             25009
# 3             25009
# 4             25009

# %% [markdown]
# # DIA 3

# %% [markdown]
# ## Colocando todos os dados de datas em formato datetime

# %%
df_final['data_emprestimo'] = pd.to_datetime(df_final['data_emprestimo'])
df_final
# Out:
#          id_emprestimo codigo_barras          data_renovacao  \
# 0               709684       L095049                     NaT
# 1               726965       L095049 2010-03-31 12:41:08.684
# 2               709685       L167050                     NaT
# 3               717763       L167050                     NaT
# 4               729996       L167050 2010-03-17 09:08:26.874
# ...                ...           ...                     ...
# 2072517        2989018    2009036492                     NaT
# 2072518        2989020    2014062640                     NaT
# 2072519        2989032    2018003324                     NaT
# 2072520        2989049    2006024313                     NaT
# 2072521        2989061    2018031352                     NaT
#
#                 data_emprestimo          data_devolucao matricula_ou_siape  \
# 0       2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1       2010-03-01 12:40:56.212 2010-04-30 14:42:35.366       2009121584.0
# 2       2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 3       2010-02-11 11:16:30.335 2010-03-04 08:54:32.262       2008050352.0
# 4       2010-03-04 13:36:26.599 2010-03-31 18:04:29.669        200722565.0
# ...                         ...                     ...                ...
# 2072517 2020-03-17 19:49:10.187 2020-12-03 08:12:20.000      20150109837.0
# 2072518 2020-03-17 19:51:15.700 2021-01-07 11:16:28.000      20190035012.0
# 2072519 2020-03-17 20:00:11.416 2021-08-30 13:29:44.000      20191021693.0
# 2072520 2020-03-17 20:47:18.741                     NaT      20150129867.0
# 2072521 2020-03-17 21:22:22.138 2021-07-26 15:05:20.000      20200005327.0
#
#            tipo_vinculo_usuario  id_exemplar            colecao  \
# 0            ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2            ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3            ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4            ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...                         ...          ...                ...
# 2072517      ALUNO DE GRADUAÇÃO       274820  Acervo Circulante
# 2072518      ALUNO DE GRADUAÇÃO      1157915  Acervo Circulante
# 2072519  ALUNO DE PÓS-GRADUAÇÃO      1317173  Acervo Circulante
# 2072520      ALUNO DE GRADUAÇÃO       206073  Acervo Circulante
# 2072521      ALUNO DE GRADUAÇÃO      1342535  Acervo Circulante
#
#                                                 biblioteca status_material  \
# 0                           Biblioteca Central Zila Mamede         REGULAR
# 1                           Biblioteca Central Zila Mamede         REGULAR
# 2                           Biblioteca Central Zila Mamede         REGULAR
# 3                           Biblioteca Central Zila Mamede         REGULAR
# 4                           Biblioteca Central Zila Mamede         REGULAR
# ...                                                    ...             ...
# 2072517                     Biblioteca Central Zila Mamede         REGULAR
# 2072518                     Biblioteca Central Zila Mamede         REGULAR
# 2072519  Biblioteca Setorial da Faculdade de Ciências d...         REGULAR
# 2072520                     Biblioteca Central Zila Mamede         REGULAR
# 2072521                     Biblioteca Central Zila Mamede         REGULAR
#
#          localizacao  registro_sistema
# 0                630              4225
# 1                630              4225
# 2                647             25009
# 3                647             25009
# 4                647             25009
# ...              ...               ...
# 2072517          676            120845
# 2072518          228            213248
# 2072519          784            255835
# 2072520          663             82178
# 2072521          355            174443
#
# [2072522 rows x 13 columns]

# %% [markdown]
# ## Criando um dataframe para armazenar apenas as informações da data do emprestimo e do id do exemplar

# %%
df_exemplaresPAno = df_final[['data_emprestimo', 'id_exemplar']]
df_exemplaresPAno
# Out:
#                 data_emprestimo  id_exemplar
# 0       2010-01-04 07:44:10.721        13259
# 1       2010-03-01 12:40:56.212        13259
# 2       2010-01-04 07:44:10.750        70865
# 3       2010-02-11 11:16:30.335        70865
# 4       2010-03-04 13:36:26.599        70865
# ...                         ...          ...
# 2072517 2020-03-17 19:49:10.187       274820
# 2072518 2020-03-17 19:51:15.700      1157915
# 2072519 2020-03-17 20:00:11.416      1317173
# 2072520 2020-03-17 20:47:18.741       206073
# 2072521 2020-03-17 21:22:22.138      1342535
#
# [2072522 rows x 2 columns]

# %% [markdown]
# ### DataFrame da quantidade de exemplares emprestados por ano

# %%
df_exemplaresPAno.loc[:, 'data_emprestimo'] = df_exemplaresPAno.loc[:, 'data_emprestimo'].dt.year
df_exemplaresPAno = df_exemplaresPAno.value_counts().groupby(['data_emprestimo']).sum().sort_values(ascending=False).to_frame('exemplares_emprestados_por_ano')
df_exemplaresPAno
# Out:
#                  exemplares_emprestados_por_ano
# data_emprestimo
# 2013                                     234749
# 2012                                     221365
# 2014                                     219189
# 2017                                     218462
# 2016                                     215900
# 2015                                     213582
# 2011                                     196390
# 2018                                     194080
# 2019                                     171801
# 2010                                     161394
# 2020                                      25610

# %% [markdown]
# ### Grafico da quantidade de exemplares emprestados por ano

# %%
df_exemplaresPAno.plot(title='Exemplares emprestados por ano', xlabel='Ano', ylabel='Quantidade de exemprestimos')
# Out:
# <Axes: title={'center': 'Exemplares emprestados por ano'}, xlabel='Ano', ylabel='Quantidade de exemprestimos'>

# %% [markdown]
# #### Análise do gráfico:
#  - 1. Aparentemente, a quantidade de emprestimos está diminuindo ao longo dos anos.

# %% [markdown]
# ### DataFrame da quantidade de exemplares por mês

# %%
df_exemplaresPMes = df_final[['data_emprestimo', 'id_exemplar']]
df_exemplaresPMes.loc[:, 'data_emprestimo'] = df_exemplaresPMes.loc[:, 'data_emprestimo'].dt.month

df_exemplaresPMes = df_exemplaresPMes.value_counts().groupby(['data_emprestimo']).sum().to_frame('exemplares_emprestados_por_mes')
df_exemplaresPMes
# Out:
#                  exemplares_emprestados_por_mes
# data_emprestimo
# 1                                         67514
# 2                                        210200
# 3                                        252185
# 4                                        208725
# 5                                        202530
# 6                                        138123
# 7                                        123790
# 8                                        232793
# 9                                        208234
# 10                                       188410
# 11                                       164222
# 12                                        75796

# %% [markdown]
# ### Grafico da quantidade de exemplares por mês

# %%
df_exemplaresPMes.plot(kind='line', title='Exemplares emprestados por mês', xlabel='Mês', ylabel='Quantidade de emprestimos')
# Out:
# <Axes: title={'center': 'Exemplares emprestados por mês'}, xlabel='Mês', ylabel='Quantidade de emprestimos'>

# %% [markdown]
# #### Análise do gráfico:
#  - 1. Possiveis meses de ferias (com menor demanda):
#   - Janeiro(1);
#   - Julho(7);
#   - Dezembro(12).
#  - 2. Periodo de meses com menor demanda para alocar atividades que não sejam de atendimento ao usuário:
#   - Dezembro - Janeiro;
#   - Junho - Julho.

# %% [markdown]
# ### Dataframe da quantidade de exemplares emprestados por hora

# %%
df_exemplaresPHora = df_final[['data_emprestimo', 'id_exemplar']]
df_exemplaresPHora.loc[:, 'data_emprestimo'] = df_exemplaresPHora.loc[:, 'data_emprestimo'].dt.hour

df_exemplaresPHora = df_exemplaresPHora.value_counts().groupby(['data_emprestimo']).sum().to_frame('exemplares_emprestados_por_hora')
df_exemplaresPHora
# Out:
#                  exemplares_emprestados_por_hora
# data_emprestimo
# 0                                             17
# 6                                             14
# 7                                          18777
# 8                                         103416
# 9                                         131273
# 10                                        185839
# 11                                        180048
# 12                                        148754
# 13                                        126987
# 14                                        150876
# 15                                        166672
# 16                                        210655
# 17                                        185340
# 18                                        182520
# 19                                        102129
# 20                                        127716
# 21                                         51191
# 22                                           247
# 23                                            51

# %% [markdown]
# ### Grafico da quantidade de exemplares emprestados por hora

# %%
df_exemplaresPHora.plot(kind='line', title='Exemplares emprestados por hora', xlabel='Hora', ylabel='Quantidade de emprestimos')
# Out:
# <Axes: title={'center': 'Exemplares emprestados por hora'}, xlabel='Hora', ylabel='Quantidade de emprestimos'>

# %% [markdown]
# #### Análise do gráfico:
#  - 1. Horarios com menor demanda para alocar atividades que não sejam de atendimento ao usuário:
#   - 22:00 - 06:00;
