# %% [markdown]
# # DIA 1

# %% [markdown]
# ## Importando as bases de dados dos emprestimos e concatenando todas.

# %%
import pandas as pd

base_url = 'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/'

files = ['emprestimos-20101.csv',
         'emprestimos-20102.csv',
         'emprestimos-20111.csv',
         'emprestimos-20112.csv',
         'emprestimos-20121.csv',
         'emprestimos-20122.csv',
         'emprestimos-20131.csv',
         'emprestimos-20132.csv',
         'emprestimos-20141.csv',
         'emprestimos-20142.csv',
         'emprestimos-20151.csv',
         'emprestimos-20152.csv',
         'emprestimos-20161.csv',
         'emprestimos-20162.csv',
         'emprestimos-20171.csv',
         'emprestimos-20172.csv',
         'emprestimos-20181.csv',
         'emprestimos-20182.csv',
         'emprestimos-20191.csv',
         'emprestimos-20192.csv',
         'emprestimos-20201.csv']


url_file_emprestimo = [base_url + file for file in files]

dfs_emprestimos = []

for url in url_file_emprestimo:
    df = pd.read_csv(url)
    dfs_emprestimos.append(df)

df_combinado_emprestimo = pd.concat(dfs_emprestimos, ignore_index=True)

# %% [markdown]
# ## Verificando se há duplicatas (Informações duplicadas)

# %%
df_combinado_emprestimo.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %% [markdown]
# ### Removendo-as:

# %%
df_combinado_emprestimo = df_combinado_emprestimo.drop_duplicates()

display(df_combinado_emprestimo.value_counts())
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 2336122        2011033079     2016/11/21 02:01:58.488000000  2016/11/10 17:00:12.989000000  2016/12/02 14:21:49.000000000  2.016023e+09        ALUNO DE GRADUAÇÃO        1
# 2336103        2014085936     2016/11/25 19:25:36.215000000  2016/11/10 16:54:52.447000000  2016/12/13 14:30:52.000000000  2.014047e+09        ALUNO DE GRADUAÇÃO        1
# 2336104        2011027960     2016/11/23 17:27:54.642000000  2016/11/10 16:55:17.956000000  2016/11/28 10:32:38.000000000  2.016083e+09        ALUNO DE GRADUAÇÃO        1
# ...

# %% [markdown]
# ## Importando a segunda base de dados (Exemplares)

# %%
database_exemplares = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')
display(database_exemplares)
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %% [markdown]
# ## Mesclando as duas bases de dados

# %%
df_final = df_combinado_emprestimo.merge(database_exemplares)
df_final.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# # DIA 2

# %% [markdown]
# ## Manipulando os dados

# %% [markdown]
# ### Adicionando uma nova conluna que coloca a classificação do número da coluna "localização"

# %% [markdown]
#  - 000 a 099: Generalidades. Ciência e conhecimento.
#  - 100 a 199: Filosofia e psicologia.
#  - 200 a 299: Religião.
#  - 300 a 399: Ciências sociais.
#  - 400 a 499: Classe vaga. Provisoriamente não ocupada.
#  - 500 a 599: Matemática e ciências naturais.
#  - 600 a 699: Ciências aplicadas.
#  - 700 a 799: Belas artes.
#  - 800 a 899: Linguagem. Língua. Linguística.
#  - 900 a 999: Geografia. Biografia. História."

# %%
def CDU_code(code):
  classification = ''
  if code < 99:
    classification = 'Generalidades. Ciência e conhecimento.'
    return classification
  elif code >= 100 and code <199:
    classification = 'Filosofia e psicologia.'
    return classification
  elif code >= 200 and code <299:
    classification = 'Religião.'
    return classification
  elif code >= 300 and code <399:
    classification = 'Ciências sociais.'
    return classification
  elif code >= 400 and code <499:
    classification = 'Classe vaga. Provisoriamente não ocupada.'
    return classification
  elif code >= 500 and code <599:
    classification = 'Matemática e ciências naturais.'
    return classification
  elif code >= 600 and code <699:
    classification = 'Ciências aplicadas.'
    return classification
  elif code >= 700 and code <799:
    classification = 'Belas artes.'
    return classification
  elif code >= 800 and code <899:
    classification = 'Linguagem. Língua. Linguística.'
    return classification
  elif code >= 900 and code <999:
    classification = 'Geografia. Biografia. História.'
    return classification
  else:
    return None

lista_classes = []

for cell in df_final['localizacao']:
  lista_classes.append(CDU_code(cell))

df_final['classe_geral'] = lista_classes

df_final.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ### Excluindo a coluna "registro_sistema" por não ter relevancia na análise

# %%
df_final = df_final.drop('registro_sistema', axis=1)
df_final.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ### Modificando o dtype da coluna "matricula_ou_siape" para string, a fim de ter uma melhor visualização

# %%
df_final['matricula_ou_siape'] = df_final['matricula_ou_siape'].astype('string')
df_final.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# # DIA 3

# %% [markdown]
# ## Colocando todos os dados de datas em formato datetime

# %%
import pandas as pd
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

df_final['data_emprestimo'] = pd.to_datetime(df_final['data_emprestimo'])
df_final
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                 data_emprestimo                 data_devolucao  \
# 0       2010-01-04 07:44:10.721  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ## Criando um dataframe para armazenar apenas as informações da data do emprestimo e do id do exemplar

# %%
df_exemplaresPAno = df_final[['data_emprestimo', 'id_exemplar']]
df_exemplaresPAno
# Out:
#                 data_emprestimo  id_exemplar
# 0       2010-01-04 07:44:10.721        13259
# 1       2010-03-01 12:40:56.212        13259
# 2       2010-01-04 07:44:10.750        70865
# 3       2010-02-11 11:16:30.335        70865
# 4       2010-03-04 13:36:26.599        70865
# ...                         ...          ...
# 2072517 2020-03-17 19:49:10.187       274820
# 2072518 2020-03-17 19:51:15.700      1157915
# 2072519 2020-03-17 20:00:11.416      1317173
# 2072520 2020-03-17 20:47:18.741       206073
# 2072521 2020-03-17 21:22:22.138      1342535
#
# [2072522 rows x 2 columns]

# %% [markdown]
# ### DataFrame da quantidade de exemplares emprestados por ano

# %%
df_exemplaresPAno.loc[:, 'data_emprestimo'] = df_exemplaresPAno.loc[:, 'data_emprestimo'].dt.year
df_exemplaresPAno = df_exemplaresPAno.value_counts().groupby(['data_emprestimo']).sum().sort_index(ascending=True).to_frame('exemplares_emprestados_por_ano')
df_exemplaresPAno
# Out:
#                  exemplares_emprestados_por_ano
# data_emprestimo
# 2010                                     161394
# 2011                                     196390
# 2012                                     221365
# 2013                                     234749
# 2014                                     219189
# 2015                                     213582
# 2016                                     215900
# 2017                                     218462
# 2018                                     194080
# 2019                                     171801
# 2020                                      25610

# %% [markdown]
# ### Grafico da quantidade de exemplares emprestados por ano

# %%
df_exemplaresPAno.plot(kind='bar', title='Exemplares emprestados por ano', xlabel='Ano', ylabel='Quantidade de exemprestimos', color='black', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Exemplares emprestados por ano'}, xlabel='Ano', ylabel='Quantidade de exemprestimos'>

# %% [markdown]
# #### Análise do gráfico:
#  - 1. Aparentemente, a quantidade de emprestimos está diminuindo ao longo dos anos.

# %% [markdown]
# ### DataFrame da quantidade de exemplares por mês

# %%
df_exemplaresPMes = df_final[['data_emprestimo', 'id_exemplar']]
df_exemplaresPMes.loc[:, 'data_emprestimo'] = df_exemplaresPMes.loc[:, 'data_emprestimo'].dt.month

df_exemplaresPMes = df_exemplaresPMes.value_counts().groupby(['data_emprestimo']).sum().to_frame('exemplares_emprestados_por_mes')
df_exemplaresPMes
# Out:
#                  exemplares_emprestados_por_mes
# data_emprestimo
# 1                                         67514
# 2                                        210200
# 3                                        252185
# 4                                        208725
# 5                                        202530
# 6                                        138123
# 7                                        123790
# 8                                        232793
# 9                                        208234
# 10                                       188410
# 11                                       164222
# 12                                        75796

# %% [markdown]
# ### Grafico da quantidade de exemplares por mês

# %%
meses = {
    1: 'Jan', 2: 'Fev', 3: 'Mar', 4: 'Abr',
    5: 'Mai', 6: 'Jun', 7: 'Jul', 8: 'Ago',
    9: 'Set', 10: 'Out', 11: 'Nov', 12: 'Dez'
}

df_exemplaresPMes.index = df_exemplaresPMes.index.map(meses)

df_exemplaresPMes.plot(kind='bar', title='Exemplares emprestados por mês', xlabel='Mês', ylabel='Quantidade de emprestimos', color='black', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Exemplares emprestados por mês'}, xlabel='Mês', ylabel='Quantidade de emprestimos'>

# %% [markdown]
# #### Análise do gráfico:
#  - 1. Possiveis meses de ferias (com menor demanda):
#   - Janeiro(1);
#   - Junho(6);
#   - Julho(7);
#   - Dezembro(12).
#  - 2. Periodo de meses com menor demanda para alocar atividades que não sejam de atendimento ao usuário:
#   - Dezembro - Janeiro;
#   - Junho - Julho.

# %% [markdown]
# ### Dataframe da quantidade de exemplares emprestados por hora

# %%
df_exemplaresPHora = df_final[['data_emprestimo', 'id_exemplar']]
df_exemplaresPHora.loc[:, 'data_emprestimo'] = df_exemplaresPHora.loc[:, 'data_emprestimo'].dt.hour

df_exemplaresPHora = df_exemplaresPHora.value_counts().groupby(['data_emprestimo']).sum().to_frame('exemplares_emprestados_por_hora')
df_exemplaresPHora
# Out:
#                  exemplares_emprestados_por_hora
# data_emprestimo
# 0                                             17
# 6                                             14
# 7                                          18777
# 8                                         103416
# 9                                         131273
# 10                                        185839
# 11                                        180048
# 12                                        148754
# 13                                        126987
# 14                                        150876
# 15                                        166672
# 16                                        210655
# 17                                        185340
# 18                                        182520
# 19                                        102129
# 20                                        127716
# 21                                         51191
# 22                                           247
# ...

# %% [markdown]
# ### Grafico da quantidade de exemplares emprestados por hora

# %%
df_exemplaresPHora.plot(kind='bar', title='Exemplares emprestados por hora', xlabel='Hora', ylabel='Quantidade de emprestimos', figsize=(10,6), color='black')
# Out:
# <Axes: title={'center': 'Exemplares emprestados por hora'}, xlabel='Hora', ylabel='Quantidade de emprestimos'>

# %% [markdown]
# #### Análise do gráfico:
#  - 1. Horarios com menor demanda para alocar atividades que não sejam de atendimento ao usuário:
#   - 22:00 - 07:00;

# %% [markdown]
# # DIA 4

# %% [markdown]
# ## Função para criação das tabelas para análise de frequencia

# %%
def tabela_frequencia(column):
  df_frenquencia = df_final[column].value_counts(normalize=True).to_frame('Percentual de frequencia')
  return df_frenquencia.round(3)

# %% [markdown]
# ## Primeira análise de frenquencia
#  - “Como se distribuem os empréstimos de exemplares pelos tipos de vínculo dos usuários?”

# %%
df_frenquencia_vinculo = tabela_frequencia('tipo_vinculo_usuario')
df_frenquencia_vinculo
# Out:
#                                  Percentual de frequencia
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                                  0.778
# ALUNO DE PÓS-GRADUAÇÃO                              0.146
# DOCENTE                                             0.034
# SERVIDOR TÉCNICO-ADMINISTRATIVO                     0.016
# ALUNO MÉDIO/TÉCNICO                                 0.014
# DOCENTE EXTERNO                                     0.012
# USUÁRIO EXTERNO                                     0.001
# OUTROS                                              0.000

# %% [markdown]
# ### Resultado:
#  - Aparentemente o público que mais frequenta a biblioteca é aluno de graduação, então:
#   - Se a estratégia de negócio não estiver sendo em cima desses alunos, possivelmente seria bastante interessante fazê-la.

# %% [markdown]
# ## Segunda análise de frequencia:
#  - "Quais coleções são mais emprestadas?"

# %%
df_frequencia_colecao = tabela_frequencia('colecao')
df_frequencia_colecao
# Out:
#                                        Percentual de frequencia
# colecao
# Acervo Circulante                                         0.991
# Multimeios                                                0.004
# Monografias                                               0.002
# Dissertações                                              0.001
# Obras de Referência                                       0.001
# Publicações de Autores do RN                              0.000
# Publicações da UFRN                                       0.000
# Teses                                                     0.000
# Folhetos                                                  0.000
# Necessidades Educacionais Específicas                     0.000
# Trabalho Acadêmico                                        0.000
# Eventos                                                   0.000
# Coleção Mossoroense                                       0.000
# Coleção Zila Mamede                                       0.000
# ...

# %% [markdown]
# ### Resultado:
#  - De acordo com a tabela, a imensa maioria das coleções que saem da biblioteca são a do Acervo Circulante, então:
#   - Se a estratégia de negócios não estiver sendo em cima dessa coleção, possivelmente seria bastante interessante fazê-la.

# %% [markdown]
# ## Terceira análise de frenquencia:
#  - "Quais são as bibliotecas com mais ou menos quantidade de empréstimos?"

# %%
df_frequencia_biblioteca = tabela_frequencia('biblioteca')
df_frequencia_biblioteca
# Out:
#                                                     Percentual de frequencia
# biblioteca
# Biblioteca Central Zila Mamede                                         0.688
# Biblioteca Setorial do Centro Ciências da Saúde...                     0.057
# Biblioteca Setorial da Faculdade de Ciências da...                     0.037
# Biblioteca Setorial Prof. Alberto Moreira Campo...                     0.032
# Biblioteca Setorial Profª. Maria Lúcia da Costa...                     0.030
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...                     0.022
# Biblioteca Setorial do Centro de Ciências Human...                     0.020
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...                     0.015
# Biblioteca Setorial Profª. Maria José Mamede Ga...                     0.014
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...                     0.013
# Biblioteca Setorial Prof. Francisco Gurgel De A...                     0.013
# ...

# %% [markdown]
# ### Resultado:
#  - Aparentemente a biblioteca mais frequentada é a Biblioteca Central Zila Mamede.
#  - As bibliotecas que estão com menos de 1% da frequencia são:
#   1. Biblioteca Setorial do Departamento de Artes - DEART;
#   2. Biblioteca Setorial Prof. Leopoldo Nelson - Centro de Biociências - CB;
#   3. Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA;
#   4. Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - CT;
#   5. Biblioteca Setorial Prof. Horácio Nicolas Solimo - Engenharia Química - EQ - CT
#   6. Biblioteca Setorial Moacyr de Góes - CE;
#   7. Biblioteca Setorial Árvore do Conhecimento - Instituto do Cérebro - ICe;
#   8. Biblioteca Setorial do Núcleo de Ensino Superior do Agreste - NESA - Nova Cruz;
#   - Então, para evitar que essas bibliotecas caiam totalmente em desuso, poderá ser feito esforços maiores para promovê-las e incentivar seu uso.
#
# - Porém não poderá ser descartado o fato que todas as outras bibliotecas, fora a Biblioteca Central Zila Mamede e a Biblioteca Setorial do Centro Ciências da Saúde - CCS, estão abaixo de 5% da frenquencia.

# %% [markdown]
# ## Quarta análise de frenquencia:
#  - "De quais temas da CDU são os exemplares emprestados?"

# %%
df_frequencia_classe = tabela_frequencia('classe_geral')
df_frequencia_classe
# Out:
#                                         Percentual de frequencia
# classe_geral
# Ciências aplicadas.                                        0.688
# Ciências sociais.                                          0.178
# Matemática e ciências naturais.                            0.033
# Generalidades. Ciência e conhecimento.                     0.030
# Religião.                                                  0.030
# Filosofia e psicologia.                                    0.029
# Belas artes.                                               0.004
# Geografia. Biografia. História.                            0.004
# Linguagem. Língua. Linguística.                            0.004

# %% [markdown]
# ### Resultado:
#  - Os temas mais procurados são:
#   1. Ciências aplicadas. (68%)
#   2. Ciências sociais. (17%)
#
#  - Os outros estão:
#   1. Matemática e ciências naturais. (3.3%)
#   2. Generalidades. Ciência e conhecimento.	(3%)
#   3. Religião. (3%)
#   4. Filosofia e psicologia. (2.9%)
#   5. Belas artes. (0.4%)
#   6. Geografia. Biografia. História. (0.4%)
#   7. Linguagem. Língua. Linguística. (0.4%)
#
# - Logo, os que estão abaixo de 10% podem ser alvo de promoção no marketing de acervo, afim de melhorar sua frequência. Porém, sem deixar de mencionar os que atualmente são maioria, com o objetivo de gerar um equilibrio entre os temas mais procurados.

# %% [markdown]
# # DIA 5

# %% [markdown]
# ## DataFrame final

# %%
df_final.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#           data_emprestimo                 data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721  2010/01/05 16:26:12.662000000       2008023265.0
# 1 2010-03-01 12:40:56.212  2010/04/30 14:42:35.366000000       2009121584.0
# 2 2010-01-04 07:44:10.750  2010/01/12 07:34:13.934000000       2008023265.0
# 3 2010-02-11 11:16:30.335  2010/03/04 08:54:32.262000000       2008050352.0
# 4 2010-03-04 13:36:26.599  2010/03/31 18:04:29.669000000        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ## Verificando a coleçao de maior frequencia dentro dos alunos de graduação

# %%
df_alunos_graduacao = df_final.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
df_alunos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        1600155
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: count, dtype: int64

# %% [markdown]
# ## Criação do dataframe que terá a quantidade de emprestimos de cada mês nos anos de 2010-2020

# %%
df_alunos_graduacao_acervo_circulante = pd.DataFrame(df_alunos_graduacao.query('colecao == "Acervo Circulante"'))
df_alunos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(df_alunos_graduacao_acervo_circulante['data_emprestimo'])
df_alunos_graduacao_acervo_circulante['ano'] = df_alunos_graduacao_acervo_circulante['data_emprestimo'].dt.year
df_alunos_graduacao_acervo_circulante['mes'] = df_alunos_graduacao_acervo_circulante['data_emprestimo'].dt.month
df_alunos_graduacao_acervo_circulante = df_alunos_graduacao_acervo_circulante.loc[:, ['ano', 'mes']]
df_alunos_graduacao_acervo_circulante = df_alunos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
df_alunos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2012    3       22797
# 1    2015    3       22483
# 2    2013    4       21853
# 3    2017    3       21735
# 4    2016    3       21692
# ..    ...  ...         ...
# 118  2016    1        2670
# 119  2019    1        2276
# 120  2019   12        1980
# 121  2020    1        1781
# 122  2011    1         809
#
# [123 rows x 3 columns]

# %% [markdown]
# ## Criação do grafico da quantidade de emprestimos de cada mês nos anos de 2010-2020

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def gera_box_plot(dataset,x,y,titulo,subtitulo):
  '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  subtitulo = subtitulo do texto
  '''

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)
  plt.figure(figsize=(16,10))

  ax = sns.boxplot(y= y, x= x, data= dataset,color='#4171EF')
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))


  plt.ylim(0,max(dataset[y])*1.1)                                               #Definir o limite do eixo y
  plt.xlabel(None)
  plt.ylabel(None)

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %%
gera_box_plot(df_alunos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de graduação no acervo circulante')

# %% [markdown]
# ## Análise do boxplot:
#  1. Levando em conta que o vinculo de aluno que mais realiza emprestiimos na biblioteca é o de graduação, e que por sua vez tem como coleção mais requisitada a do Acervo Circulante, este boxplot pode ser visto como grande parte do conjunto de dados fornecidos.
#
#  2. Nos anos de 2010-2013 houveram um aumento significativo de emprestimos, tendo um declinio em 2014, porém um mais acentuado em 2019-2020, provavelmente por conta da pandemia.
#
#  3. De 2014-2017 houve um "equilibrio" nos emprestimos, onde o q3 se manteve quase na mesma linha durante esse período.
#
#  4. Dessa forma, cabe uma análise profunda das estrategias ed negocio tomadas em 2010-2013 para identificar o que ajudou a ter um aumento constante e, em contrapartida, identificar o que houve a partir de 2014. Feito isso, a direção pode tomar estrategias de 2010-2013, adaptadas para os tempos atuais, e tambem rever as estrategias tomadas em 2014 que geraram o declino, afim de não se repetir mais.

# %% [markdown]
# ## Verificando a coleçao de maior frequencia dentro dos alunos de pos-graduação

# %%
df_alunos_pos_graduacao = df_final.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
df_alunos_pos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        299201
# Dissertações                                934
# Obras de Referência                         700
# Multimeios                                  559
# Teses                                       367
# Monografias                                 278
# Publicações de Autores do RN                204
# Publicações da UFRN                         121
# Folhetos                                     60
# Necessidades Educacionais Específicas        30
# Eventos                                      26
# Coleção Mossoroense                          23
# Trabalho Acadêmico                           23
# Coleção Zila Mamede                          11
# Literatura de Cordel                          4
# Name: count, dtype: int64

# %% [markdown]
# ## Criação do dataframe que terá a quantidade de emprestimos de cada mês nos anos de 2010-2020

# %%
df_alunos_pos_graduacao_acervo_circulante = pd.DataFrame(df_alunos_pos_graduacao.query('colecao == "Acervo Circulante"'))
df_alunos_pos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(df_alunos_pos_graduacao_acervo_circulante['data_emprestimo'])
df_alunos_pos_graduacao_acervo_circulante['ano'] = df_alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.year
df_alunos_pos_graduacao_acervo_circulante['mes'] = df_alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.month
df_alunos_pos_graduacao_acervo_circulante = df_alunos_pos_graduacao_acervo_circulante.loc[:, ['ano', 'mes']]
df_alunos_pos_graduacao_acervo_circulante = df_alunos_pos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
df_alunos_pos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2015    3        3927
# 1    2017    8        3837
# 2    2017    3        3722
# 3    2016    3        3711
# 4    2016    8        3662
# ..    ...  ...         ...
# 119  2020    1        1143
# 120  2010    1        1105
# 121  2019   12        1069
# 122  2011    1         465
# 123  2020    6           2
#
# [124 rows x 3 columns]

# %% [markdown]
# ## Criação do boxplot

# %%
gera_box_plot(df_alunos_pos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de pos-graduação no acervo circulante')

# %% [markdown]
# ## Análise do boxplot:
#  1. Parecido com os alunos de graduação, os de pós-graduação tiveram um aumento significativo nos anos de 2010-2013, porém no ano de 2014 aumentou novamente a quantidade de empréstimos.
#
#  2. Também paracido com os alunos de graduação, os de pós-graduação se mantiveram constantes nos anos de 2014-2017, porém com um aumento no ano de 2016, e um incio de declinio no ano de 2018.
#
#  3. De forma parecida com a conclusão tirada no boxplot anterior, a direção da pode fazer uma análise mais profunda nas estratégias tomadas nos anos de 2013-2017 - em especial em 2016 - para aplicá-las, adaptadas para os tempos atuais, afim de alavancar novamente os emprestimos entre os alunos de pós-graduação.

# %% [markdown]
# # DIA 6

# %% [markdown]
# ## Importação de uma parte da base de dados em JSON

# %%
json_data = pd.read_json('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json')
df_json_data = pd.read_json(json_data.registros[0])
df_json_data.head()
# Out:
#    matricula_ou_siape tipo_vinculo_usuario                   curso
# 0          2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1           200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2           200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3           200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4           200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO

# %% [markdown]
# ### Tratando essa base de dados

# %%
df_json_data.matricula_ou_siape = df_json_data.matricula_ou_siape.astype('float64')
df_json_data.matricula_ou_siape = df_json_data.matricula_ou_siape.astype('string')
df_json_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  string
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: object(2), string(1)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Importação da outra parte da base de dados em Excel

# %% [markdown]
# ### Excel até 2010

# %% [markdown]
# #### Importação

# %%
excel_data_ate2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                   sheet_name= 'Até 2010',skiprows=1)
excel_data_ate2010.head()
# Out:
#    Número da matrícula     Tipo de vinculo                Curso
# 0          190001688.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1          199014489.0  ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2          199735674.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3          199812431.0  ALUNO DE GRADUAÇÃO               LETRAS
# 4          199823670.0  ALUNO DE GRADUAÇÃO             ECOLOGIA

# %% [markdown]
# #### Tratamento

# %%
excel_data_ate2010.rename(columns={'Número da matrícula': 'matricula_ou_siape','Tipo de vinculo': 'tipo_vinculo_usuario', 'Curso': 'curso'}, inplace=True)
excel_data_ate2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7726 entries, 0 to 7725
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    7726 non-null   float64
#  1   tipo_vinculo_usuario  7726 non-null   object
#  2   curso                 7726 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 181.2+ KB

# %%
excel_data_ate2010.matricula_ou_siape = excel_data_ate2010.matricula_ou_siape.astype('string')
excel_data_ate2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7726 entries, 0 to 7725
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    7726 non-null   string
#  1   tipo_vinculo_usuario  7726 non-null   object
#  2   curso                 7726 non-null   object
# dtypes: object(2), string(1)
# memory usage: 181.2+ KB

# %%
excel_data_ate2010.head()
# Out:
#   matricula_ou_siape tipo_vinculo_usuario                curso
# 0        190001688.0   ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1        199014489.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2        199735674.0   ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3        199812431.0   ALUNO DE GRADUAÇÃO               LETRAS
# 4        199823670.0   ALUNO DE GRADUAÇÃO             ECOLOGIA

# %% [markdown]
# ### Excel depois de 2010

# %% [markdown]
# #### Importação

# %%
excel_data_depois2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                    sheet_name='Após 2010',skiprows=1)
excel_data_depois2010.head(90)
# Out:
#       Matricula      Tipo de vinculo                 Cursos
# 0   2.010000e+09  ALUNO DE GRADUAÇÃO                DIREITO
# 1   2.010000e+09  ALUNO DE GRADUAÇÃO              AGRONOMIA
# 2   2.010001e+09  ALUNO DE GRADUAÇÃO     ENGENHARIA QUÍMICA
# 3   2.010003e+09  ALUNO DE GRADUAÇÃO   ENGENHARIA AMBIENTAL
# 4   2.010003e+09  ALUNO DE GRADUAÇÃO              GEOGRAFIA
# ..           ...                 ...                    ...
# 85  2.010015e+09  ALUNO DE GRADUAÇÃO                TURISMO
# 86  2.010015e+09  ALUNO DE GRADUAÇÃO           FISIOTERAPIA
# 87  2.010015e+09  ALUNO DE GRADUAÇÃO  CIÊNCIA DA COMPUTAÇÃO
# 88  2.010015e+09  ALUNO DE GRADUAÇÃO                 LETRAS
# 89  2.010015e+09  ALUNO DE GRADUAÇÃO    CIÊNCIAS BIOLÓGICAS
#
# [90 rows x 3 columns]

# %% [markdown]
# #### Tratamento

# %%
excel_data_depois2010.columns=['matricula_ou_siape','tipo_vinculo_usuario','curso']
excel_data_depois2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2274 entries, 0 to 2273
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    2274 non-null   float64
#  1   tipo_vinculo_usuario  2274 non-null   object
#  2   curso                 2274 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 53.4+ KB

# %%
excel_data_depois2010.matricula_ou_siape = excel_data_depois2010.matricula_ou_siape.astype('string')
excel_data_depois2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2274 entries, 0 to 2273
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    2274 non-null   string
#  1   tipo_vinculo_usuario  2274 non-null   object
#  2   curso                 2274 non-null   object
# dtypes: object(2), string(1)
# memory usage: 53.4+ KB

# %% [markdown]
# ### Junção das bases de dados do excel

# %%
df_excel_data = pd.concat([excel_data_ate2010, excel_data_depois2010])
df_excel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 2273
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    10000 non-null  string
#  1   tipo_vinculo_usuario  10000 non-null  object
#  2   curso                 10000 non-null  object
# dtypes: object(2), string(1)
# memory usage: 312.5+ KB

# %% [markdown]
# ## Concatenando as duas bases de dados

# %%
df_cadastro_alunos = pd.concat([df_json_data, df_excel_data], ignore_index=True)
df_cadastro_alunos
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           2009029003.0   ALUNO DE GRADUAÇÃO                 FILOSOFIA
# 1            200617346.0   ALUNO DE GRADUAÇÃO                   DIREITO
# 2            200746502.0   ALUNO DE GRADUAÇÃO    ENGENHARIA DE PETRÓLEO
# 3            200504968.0   ALUNO DE GRADUAÇÃO             ADMINISTRAÇÃO
# 4            200615572.0   ALUNO DE GRADUAÇÃO     CIÊNCIA DA COMPUTAÇÃO
# ...                  ...                  ...                       ...
# 72797      20150116770.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 72798       2015074523.0   ALUNO DE GRADUAÇÃO                     DANÇA
# 72799      20160002745.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 72800      20170086533.0   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 72801      20180090351.0   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [72802 rows x 3 columns]

# %% [markdown]
# ## Dataframe dos emprestimos realizadas pelos alunos de graduação de 2015-2020

# %%
matricula_alunos = df_final.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
matricula_alunos = matricula_alunos.loc[:, ["matricula_ou_siape", "data_emprestimo"]]
matricula_alunos = matricula_alunos.query('data_emprestimo > 2015').reset_index(drop=True)
#Tirando valores nulos
matricula_alunos = matricula_alunos.dropna()
matricula_alunos.head(6)
# Out:
#   matricula_ou_siape         data_emprestimo
# 0       2014083920.0 2015-02-03 14:56:17.005
# 1       2014083949.0 2015-03-06 13:16:57.907
# 2       2014083920.0 2015-04-06 16:58:10.691
# 3       2014083920.0 2015-05-27 17:39:48.592
# 4       2014084089.0 2015-07-28 17:46:49.875
# 5       2013043297.0 2016-02-16 16:39:45.480

# %% [markdown]
# ## Filtrando os cursos selecionados

# %%
cursos_selecionados = df_cadastro_alunos.query('curso == ["BIBLIOTECONOMIA","CIÊNCIAS SOCIAIS","COMUNICAÇÃO SOCIAL","DIREITO","FILOSOFIA","PEDAGOGIA"]').reset_index(drop=True)
cursos_selecionados.head()
# Out:
#   matricula_ou_siape tipo_vinculo_usuario             curso
# 0       2009029003.0   ALUNO DE GRADUAÇÃO         FILOSOFIA
# 1        200617346.0   ALUNO DE GRADUAÇÃO           DIREITO
# 2        200604856.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 3        200711601.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 4       2008016110.0   ALUNO DE GRADUAÇÃO         PEDAGOGIA

# %% [markdown]
# ## Unindo em um só Dataframe a o ano

# %%
df_cadastro_alunos_selecionados = matricula_alunos.merge(cursos_selecionados)
df_cadastro_alunos_selecionados.data_emprestimo = df_cadastro_alunos_selecionados.data_emprestimo.dt.year
df_cadastro_alunos_selecionados.head()
# Out:
#   matricula_ou_siape  data_emprestimo tipo_vinculo_usuario            curso
# 0      20180154181.0             2018   ALUNO DE GRADUAÇÃO  BIBLIOTECONOMIA
# 1      20180154181.0             2020   ALUNO DE GRADUAÇÃO  BIBLIOTECONOMIA
# 2      20180154181.0             2018   ALUNO DE GRADUAÇÃO  BIBLIOTECONOMIA
# 3      20180154181.0             2018   ALUNO DE GRADUAÇÃO  BIBLIOTECONOMIA
# 4      20180154181.0             2018   ALUNO DE GRADUAÇÃO  BIBLIOTECONOMIA

# %% [markdown]
# ## Dataframe da quantidade de emprestimos por ano dos cursos selecionados

# %%
df_emprestimo_curso_selecionado = df_cadastro_alunos_selecionados.iloc[:, [1, 3]].value_counts().to_frame('QUANTIDADE_EMPRESTIMOS').reset_index()
df_emprestimo_curso_selecionado.columns = ['ANO', 'CURSO', 'QUANTIDADE_EMPRESTIMOS']
df_emprestimo_curso_selecionado.head()
# Out:
#     ANO               CURSO  QUANTIDADE_EMPRESTIMOS
# 0  2017  COMUNICAÇÃO SOCIAL                    8253
# 1  2016  COMUNICAÇÃO SOCIAL                    7973
# 2  2017             DIREITO                    7885
# 3  2015     BIBLIOTECONOMIA                    7784
# 4  2015             DIREITO                    7665

# %% [markdown]
# ## Gerando uma Pivot Table para os emprestimos dos cursos selecionados

# %%
df_emprestimo_curso_selecionado_pivot = df_emprestimo_curso_selecionado.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS',
        fill_value = '-',
        aggfunc= sum,
        margins = True,
        margins_name = 'TOTAL',
)
df_emprestimo_curso_selecionado_pivot
# Out:
# ANO                  2015   2016   2017   2018   2019  2020   TOTAL
# CURSO
# BIBLIOTECONOMIA      7784   7044   7307   6378   5889   900   35302
# CIÊNCIAS SOCIAIS     7489   6978   6918   6181   5788   825   34179
# COMUNICAÇÃO SOCIAL   7147   7973   8253   6953   5885   796   37007
# DIREITO              7665   7363   7885   7027   5861   905   36706
# FILOSOFIA            6950   7576   7389   6296   5572   832   34615
# PEDAGOGIA            7189   7153   7434   6518   5869   866   35029
# TOTAL               44224  44087  45186  39353  34864  5124  212838

# %% [markdown]
# # DIA 7

# %% [markdown]
# ## Importando a mesma base de dados JSON, porém dessa vez exibindo apenas os alunos de pós-graduação

# %%
json_data = pd.read_json('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json')
df_json_data = pd.read_json(json_data.registros[1])
df_json_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19440 entries, 0 to 19439
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    19440 non-null  int64
#  1   tipo_vinculo_usuario  19440 non-null  object
#  2   curso                 19440 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 455.8+ KB

# %% [markdown]
# ## Modificando o tipo de dado da matricula

# %%
df_json_data.matricula_ou_siape = df_json_data.matricula_ou_siape.astype('float64')
df_json_data.matricula_ou_siape = df_json_data.matricula_ou_siape.astype('string')
df_json_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19440 entries, 0 to 19439
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    19440 non-null  string
#  1   tipo_vinculo_usuario  19440 non-null  object
#  2   curso                 19440 non-null  object
# dtypes: object(2), string(1)
# memory usage: 455.8+ KB

# %% [markdown]
# ## Concatenando os dataframes da database em JSON e EXCEL

# %%
cadastro_usuarios_pos_graduacao = pd.concat([df_json_data, df_excel_data], ignore_index=True)
cadastro_usuarios_pos_graduacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29440 entries, 0 to 29439
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    29440 non-null  string
#  1   tipo_vinculo_usuario  29440 non-null  object
#  2   curso                 29440 non-null  object
# dtypes: object(2), string(1)
# memory usage: 690.1+ KB

# %% [markdown]
# ## Selecionando apenas os vinculos com pós-graduação

# %%
cadastro_usuarios_pos_graduacao = cadastro_usuarios_pos_graduacao.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"').reset_index(drop=True)
cadastro_usuarios_pos_graduacao.head()
# Out:
#   matricula_ou_siape    tipo_vinculo_usuario                    curso
# 0       2008112114.0  ALUNO DE PÓS-GRADUAÇÃO   CIÊNCIAS ODONTOLÓGICAS
# 1       2008106583.0  ALUNO DE PÓS-GRADUAÇÃO   ENGENHARIA DE SOFTWARE
# 2       2011101417.0  ALUNO DE PÓS-GRADUAÇÃO  ARQUITETURA E URBANISMO
# 3       2011113122.0  ALUNO DE PÓS-GRADUAÇÃO                FILOSOFIA
# 4       2010110903.0  ALUNO DE PÓS-GRADUAÇÃO            ARTES CÊNICAS

# %% [markdown]
# ## Dataframe da quantidade de empréstimos feito pelos alunos de pós-graduação a partir de 2017

# %%
emprestimos_pos_graduacao_apos_2017 = df_final.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
emprestimos_pos_graduacao_apos_2017 = emprestimos_pos_graduacao_apos_2017.loc[:, ["matricula_ou_siape", "data_emprestimo"]]
emprestimos_pos_graduacao_apos_2017 = emprestimos_pos_graduacao_apos_2017.query('data_emprestimo > 2017').reset_index(drop=True)
# Tirando os valores nulos
emprestimos_pos_graduacao_apos_2017 = emprestimos_pos_graduacao_apos_2017.dropna()
emprestimos_pos_graduacao_apos_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92112 entries, 0 to 92122
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   matricula_ou_siape  92112 non-null  string
#  1   data_emprestimo     92112 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), string(1)
# memory usage: 2.1 MB

# %% [markdown]
# ## Modificando o tipo da data para mostrar apenas o ano

# %%
df_emprestimos_pos_graduacao_apos_2017 = emprestimos_pos_graduacao_apos_2017.merge(cadastro_usuarios_pos_graduacao)
df_emprestimos_pos_graduacao_apos_2017.data_emprestimo = df_emprestimos_pos_graduacao_apos_2017.data_emprestimo.dt.year
df_emprestimos_pos_graduacao_apos_2017.head()
# Out:
#   matricula_ou_siape  data_emprestimo    tipo_vinculo_usuario      curso
# 0      20171029059.0             2017  ALUNO DE PÓS-GRADUAÇÃO  FILOSOFIA
# 1      20171029059.0             2017  ALUNO DE PÓS-GRADUAÇÃO  FILOSOFIA
# 2      20171029059.0             2017  ALUNO DE PÓS-GRADUAÇÃO  FILOSOFIA
# 3      20171029059.0             2018  ALUNO DE PÓS-GRADUAÇÃO  FILOSOFIA
# 4      20171029059.0             2018  ALUNO DE PÓS-GRADUAÇÃO  FILOSOFIA

# %% [markdown]
# ## Criando um dataframe que mostra a quantidade de emprestimos dos cursos de pos graduação a cada ano

# %%
df_emprestimos_pos_graduacao_apos_2017 = df_emprestimos_pos_graduacao_apos_2017.iloc[:, [1, 3]].value_counts().to_frame('QUANTIDADE_EMPRESTIMOS').reset_index()
df_emprestimos_pos_graduacao_apos_2017.columns = ['ANO', 'CURSO', 'QUANTIDADE_EMPRESTIMOS']
df_emprestimos_pos_graduacao_apos_2017.head()
# Out:
#     ANO                           CURSO  QUANTIDADE_EMPRESTIMOS
# 0  2018          CIÊNCIAS ODONTOLÓGICAS                    2540
# 1  2017                   ADMINISTRAÇÃO                    2538
# 2  2017          ENGENHARIA DE SOFTWARE                    2477
# 3  2017               CIÊNCIAS DA SAÚDE                    2434
# 4  2017  CIÊNCIA, TECNOLOGIA E INOVAÇÃO                    2415

# %% [markdown]
# ## Criando uma tabela pivotada para melhorar a visualização

# %%
df_emprestimos_pos_graduacao_apos_2017_pivot = df_emprestimos_pos_graduacao_apos_2017.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS',

)
df_emprestimos_pos_graduacao_apos_2017_pivot
# Out:
# ANO                                     2017  2018  2019  2020
# CURSO
# ADMINISTRAÇÃO                           2538  2316  1692   269
# ARQUITETURA E URBANISMO                 2209  1917  1818   257
# ARTES CÊNICAS                           2115  2082  1812   229
# BIOINFORMÁTICA                          2190  1914  1825   263
# BIOQUÍMICA                              2294  1944  2057   272
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316  2110  2008   328
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415  2365  2026   303
# CIÊNCIAS DA SAÚDE                       2434  1986  1825   234
# CIÊNCIAS ODONTOLÓGICAS                  2414  2540  2134   352
# DESIGN                                  2272  1838  1841   254
# ENGENHARIA CIVIL                        2399  2089  1989   254
# ENGENHARIA DE SOFTWARE                  2477  2222  1887   264
# FILOSOFIA                               2170  2048  1773   302
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  2266  1891  1771   252

# %% [markdown]
# ## Importando a base de dados de previsão para 2022

# %%
previsao_2022 = pd.read_table('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_7-Apresentando_resultados_em_HTML/Dataset/previsao')
previsao_2022.head()
# Out:
#             curso previsao_2022
# 0            administracao 1905
# 1  arquitetura_e_urbanismo 1896
# 2            artes_cenicas 1920
# 3           bioinformatica 2302
# 4               bioquimica 2090

# %% [markdown]
# ## Separando o curso do valor da quantidade de emprestimos

# %%
previsao_2022 = previsao_2022['curso previsao_2022'].str.split(' ', expand=True)
previsao_2022.head()
# Out:
#                          0     1
# 0            administracao  1905
# 1  arquitetura_e_urbanismo  1896
# 2            artes_cenicas  1920
# 3           bioinformatica  2302
# 4               bioquimica  2090

# %% [markdown]
# ## Adicionando a previsão na tabela pivotada

# %%
previsao_2022.index = df_emprestimos_pos_graduacao_apos_2017_pivot.index
previsao_2022.head()
# Out:
#                                                0     1
# CURSO
# ADMINISTRAÇÃO                      administracao  1905
# ARQUITETURA E URBANISMO  arquitetura_e_urbanismo  1896
# ARTES CÊNICAS                      artes_cenicas  1920
# BIOINFORMÁTICA                    bioinformatica  2302
# BIOQUÍMICA                            bioquimica  2090

# %%
df_emprestimos_pos_graduacao_apos_2017_pivot[2022] = previsao_2022[1].astype(int)
df_emprestimos_pos_graduacao_apos_2017_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, ADMINISTRAÇÃO to GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2017    14 non-null     int64
#  1   2018    14 non-null     int64
#  2   2019    14 non-null     int64
#  3   2020    14 non-null     int64
#  4   2022    14 non-null     int64
# dtypes: int64(5)
# memory usage: 672.0+ bytes

# %%
df_emprestimos_pos_graduacao_apos_2017_pivot
# Out:
# ANO                                     2017  2018  2019  2020  2022
# CURSO
# ADMINISTRAÇÃO                           2538  2316  1692   269  1905
# ARQUITETURA E URBANISMO                 2209  1917  1818   257  1896
# ARTES CÊNICAS                           2115  2082  1812   229  1920
# BIOINFORMÁTICA                          2190  1914  1825   263  2302
# BIOQUÍMICA                              2294  1944  2057   272  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316  2110  2008   328  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415  2365  2026   303  1960
# CIÊNCIAS DA SAÚDE                       2434  1986  1825   234  1730
# CIÊNCIAS ODONTOLÓGICAS                  2414  2540  2134   352  2405
# DESIGN                                  2272  1838  1841   254  1900
# ENGENHARIA CIVIL                        2399  2089  1989   254  1920
# ENGENHARIA DE SOFTWARE                  2477  2222  1887   264  1890
# ...

# %% [markdown]
# ## Função que calculará a diferença percentual

# %%
def diferenca_percentual_ano_anterior(x,y):
  return round(((x / y * 100) - 100),2)

# %%
percentual_2017_2018 = diferenca_percentual_ano_anterior(df_emprestimos_pos_graduacao_apos_2017_pivot[2018], df_emprestimos_pos_graduacao_apos_2017_pivot[2017])
percentual_2018_2019 = diferenca_percentual_ano_anterior(df_emprestimos_pos_graduacao_apos_2017_pivot[2019], df_emprestimos_pos_graduacao_apos_2017_pivot[2018])
percentual_2019_2022 = diferenca_percentual_ano_anterior(df_emprestimos_pos_graduacao_apos_2017_pivot[2022], df_emprestimos_pos_graduacao_apos_2017_pivot[2019])

# %%
df_percentual = pd.DataFrame({
    '2018': percentual_2017_2018,
    '2019': percentual_2018_2019,
    '2022': percentual_2019_2022
})
df_percentual
# Out:
#                                          2018   2019   2022
# CURSO
# ADMINISTRAÇÃO                           -8.75 -26.94  12.59
# ARQUITETURA E URBANISMO                -13.22  -5.16   4.29
# ARTES CÊNICAS                           -1.56 -12.97   5.96
# BIOINFORMÁTICA                         -12.60  -4.65  26.14
# BIOQUÍMICA                             -15.26   5.81   1.60
# CIÊNCIA E ENGENHARIA DE MATERIAIS       -8.89  -4.83   0.10
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          -2.07 -14.33  -3.26
# CIÊNCIAS DA SAÚDE                      -18.41  -8.11  -5.21
# CIÊNCIAS ODONTOLÓGICAS                   5.22 -15.98  12.70
# DESIGN                                 -19.10   0.16   3.20
# ENGENHARIA CIVIL                       -12.92  -4.79  -3.47
# ENGENHARIA DE SOFTWARE                 -10.29 -15.08   0.16
# FILOSOFIA                               -5.62 -13.43   7.33
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO -16.55  -6.35   4.74

# %%
df_percentual.reset_index(inplace=True)
df_percentual.columns = df_percentual.columns.str.capitalize()
df_percentual.Curso = df_percentual.Curso.str.capitalize()
df_percentual
# Out:
#                                      Curso   2018   2019   2022
# 0                            Administração  -8.75 -26.94  12.59
# 1                  Arquitetura e urbanismo -13.22  -5.16   4.29
# 2                            Artes cênicas  -1.56 -12.97   5.96
# 3                           Bioinformática -12.60  -4.65  26.14
# 4                               Bioquímica -15.26   5.81   1.60
# 5        Ciência e engenharia de materiais  -8.89  -4.83   0.10
# 6           Ciência, tecnologia e inovação  -2.07 -14.33  -3.26
# 7                        Ciências da saúde -18.41  -8.11  -5.21
# 8                   Ciências odontológicas   5.22 -15.98  12.70
# 9                                   Design -19.10   0.16   3.20
# 10                        Engenharia civil -12.92  -4.79  -3.47
# 11                  Engenharia de software -10.29 -15.08   0.16
# 12                               Filosofia  -5.62 -13.43   7.33
# 13  Gestão da informação e do conhecimento -16.55  -6.35   4.74

# %% [markdown]
# ## Estrutuando o HTML

# %% [markdown]
# ### Estilizando com CSS

# %%
th_props = [
  ('font-size', '1.4rem'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'whitesmoke'),
  ('background-color', '#001692'),
  ('border-radius', '0.25rem'),
  ('box-shadow','0 0 1rem gray')
  ]

td_props = [
  ('font-size', '1rem'),
  ('padding','0.5rem'),
  ('text-align', 'left'),
  ('font-weight', 'bold'),
  ('border-bottom','0.1rem solid lightgray')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# %% [markdown]
# ### Criando tabela HTML

# %%
df_percentual.style.text_gradient(cmap='RdYlGn',low=1, axis=1,vmax=0.1,vmin=0)\
                              .format('{:.2f} %',subset=['2018','2019','2022'])\
                              .set_table_styles(styles)\
                              .to_html('teste.html',doctype_html =True,
                                       table_attributes='ALIGN=LEFT WIDTH=50% CELLSPACING = 5',
                                       index=False) # Remove o index na tabela HTML
